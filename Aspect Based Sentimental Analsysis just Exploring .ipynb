# %%
import numpy as np 
import pandas as pd

# %%
import os
import re

# %%
df_csv = pd.read_csv('Scraped_Car_Review_dodge.csv', engine= 'python', index_col=False)

# %%
df_csv.head()
# Out:
#   Unnamed: 0                  Review_Date   Author_Name  \
# 0          0   on 10/13/05 15:30 PM (PDT)     roadking
# 1          1   on 07/17/05 21:59 PM (PDT)         Mark
# 2          2   on 07/16/02 00:00 AM (PDT)    Tom Sheer
# 3          3   on 12/29/07 21:57 PM (PST)  Keven Smith
# 4          4   on 02/09/05 18:52 PM (PST)       VanMan
#
#                                        Vehicle_Title  \
# 0  2002 Dodge Ram Cargo Van 1500 3dr Van (3.9L 6c...
# 1  2002 Dodge Ram Cargo Van 3500 3dr Ext Van (5.2...
# 2  2002 Dodge Ram Cargo Van 3500 Maxi 3dr Ext Van...
# 3  2001 Dodge Ram Cargo Van 2500 Maxi 3dr Ext Van...
# 4  2001 Dodge Ram Cargo Van 1500 3dr Van (3.9L 6c...
#
#                 Review_Title  \
# 0     Great delivery vehicle
# 1             Disappointmnet
# 2                  Sweet van
# 3                Keven Smith
# 4  Not what Dodge used to be
#
#                                               Review  Rating
# 0   It's been a great delivery vehicle for my caf...   4.625
# 1   Bought this car as a commuter vehicle for a v...   2.125
# 2   This van rocks its the best, lots of \rroom. ...   5.000
# 3   Great work vehicle. Drives nice. has lots of ...   4.500
# 4   Good solid frame and suspension.  Well equipp...   2.875

# %%
len(df_csv)
# Out:
# 11552

# %%
df_csv.columns
# Out:
# Index(['Unnamed: 0', 'Review_Date', 'Author_Name', 'Vehicle_Title',
#        'Review_Title', 'Review', 'Rating'],
#       dtype='object')

# %%
df_csv['review'] = df_csv['Review_Title'] + df_csv['Review']

# %%
#Dependency parsing of the review data

import spacy
from tqdm import tqdm
nlp = spacy.load('en_core_web_lg')
# Out:
# 2022-02-22 11:59:18.864330: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-22 11:59:18.864374: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#Exploring the dependency relations between the words 

txt = 'Great car and has long range'
doc = nlp(txt)
spacy.displacy.render(doc, style='dep', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b25ce4ed66564aa4836eb780d58a4e6b-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">long</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">range</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b25ce4ed66564aa4836eb780d58a4e6b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
txt = "Drives well has great handling"
doc = nlp(txt)
spacy.displacy.render(doc, style='dep', jupyter= True )
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4c56c583fcf445659adafc11041b4e45-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Drives</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">well</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">handling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4c56c583fcf445659adafc11041b4e45-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4c56c583fcf445659adafc11041b4e45-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4c56c583fcf445659adafc11041b4e45-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4c56c583fcf445659adafc11041b4e45-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4c56c583fcf445659adafc11041b4e45-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4c56c583fcf445659adafc11041b4e45-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4c56c583fcf445659adafc11041b4e45-0-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4c56c583fcf445659adafc11041b4e45-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Compound words -> look for possible compound words check with the aspect word -> add more details to the extracted aspects while the compound word search will identify passenger van as a compound word

# %%
for sentence in df_csv['review']:
    doc = nlp(sentence)
    for token in doc:
         print(token.text, token.dep_, token.head.text, token.head.pos_,
      token.pos_,[child for child in token.children])
# Out:
# Great amod vehicle NOUN ADJ []
# delivery compound vehicle NOUN NOUN []
# vehicle dep been AUX NOUN [Great, delivery]
# It nsubjpass been AUX PRON []
# 's auxpass been AUX AUX []
# been ROOT been AUX AUX [vehicle, It, 's, vehicle, taken]
# a det vehicle NOUN DET []
# great amod vehicle NOUN ADJ []
# delivery compound vehicle NOUN NOUN []
# vehicle attr been AUX NOUN [a, great, delivery, for]
# for prep vehicle NOUN ADP [power]
# my poss cafe NOUN PRON []
# cafe nmod business NOUN NOUN [my]
# business nmod power NOUN NOUN [cafe]
# good compound power NOUN PROPN []
# power pobj for ADP NOUN [business, good]
# , punct taken VERB PUNCT []
# economy compound match NOUN NOUN []
# match nsubj taken VERB NOUN [economy]
# easily advmod taken VERB ADV []
# taken conj been AUX VERB [,, match, easily, care, of, .]
# care dobj taken VERB NOUN []
# of prep taken VERB ADP []
# . punct taken VERB PUNCT []
# Have aux repaired VERB AUX []
# nt neg repaired VERB PART []
# repaired ROOT repaired VERB VERB [Have, nt, anything, or, replaced, .]
# anything dobj repaired VERB PRON []
# or cc repaired VERB CCONJ []
# replaced conj repaired VERB VERB [anything]
# anything dobj replaced VERB PRON [but]
# but prep anything PRON SCONJ [tires]
# tires pobj but SCONJ NOUN [and, items]
# and cc tires NOUN CCONJ []
# normal amod items NOUN ADJ []
# maintenance compound items NOUN NOUN []
# items conj tires NOUN NOUN [normal, maintenance]
# . punct repaired VERB PUNCT []
# Upgraded csubj helped VERB VERB [tires, to]
# tires dobj Upgraded VERB NOUN []
# to prep Upgraded VERB ADP [series]
# Michelin compound LX PROPN PROPN []
# LX compound series NOUN PROPN [Michelin]
# series pobj to ADP NOUN [LX]
# helped ROOT helped VERB VERB [Upgraded, economy, .]
# fuel compound economy NOUN NOUN []
# economy dobj helped VERB NOUN [fuel]
# . punct helped VERB PUNCT []
# Would aux buy VERB AUX []
# buy ROOT buy VERB VERB [Would, another, in]
# another dobj buy VERB PRON []
# in prep buy VERB ADP [second]
# a det second ADJ DET []
# second pobj in ADP ADJ [a]
# Disappointmnet nsubj Bought VERB PROPN []
# Bought ROOT Bought VERB VERB [Disappointmnet, car, as, .]
# this det car NOUN DET []
# car dobj Bought VERB NOUN [this]
# as prep Bought VERB ADP [vehicle]
# a det vehicle NOUN DET []
# commuter compound vehicle NOUN NOUN []
# vehicle pobj as ADP NOUN [a, commuter, for]
# for prep vehicle NOUN ADP [pool]
# a det pool NOUN DET []
# van compound pool NOUN PROPN []
# pool pobj for ADP NOUN [a, van]
# . punct Bought VERB PUNCT []
#   dep was AUX SPACE []
# I nsubj was AUX PRON []
# was ROOT was AUX AUX [ , I, disappointed, in, .]
# very advmod disappointed ADJ ADV []
# disappointed acomp was AUX ADJ [very, in]
# in prep disappointed ADJ ADP [vehicle]
# the det vehicle NOUN DET []
# vehicle pobj in ADP NOUN [the]
# in prep was AUX ADP [comparison]
# comparison pobj in ADP NOUN [to]
# to prep comparison NOUN ADP [model]
# a det model NOUN DET []
# 1997 nummod model NOUN NUM []
# model pobj to ADP NOUN [a, 1997, had]
# I nsubj had VERB PRON []
# had relcl model NOUN VERB [I, previously]
# previously advmod had VERB ADV []
# . punct was AUX PUNCT []
#   dep was AUX SPACE []
# The det motor NOUN DET []
# motor nsubj was AUX NOUN [The]
# was ROOT was AUX AUX [ , motor, sluggish, and, tended, .]
# sluggish acomp was AUX ADJ []
# and cc was AUX CCONJ []
# tended conj was AUX VERB [have]
# to aux have VERB PART []
# have xcomp tended VERB VERB [to, idle]
# a det idle NOUN DET []
# rough amod idle NOUN ADJ []
# idle dobj have VERB NOUN [a, rough]
# . punct was AUX PUNCT []
#   dep C PROPN SPACE []
# The det C PROPN DET []
# A nmod C PROPN PROPN []
# / punct C PROPN SYM []
# C nsubj was AUX PROPN [ , The, A, /]
# was ROOT was AUX AUX [C, better, ,, but, lacked, .]
# better acomp was AUX ADJ [than]
# than prep better ADJ ADP [van]
# the det van NOUN DET []
# old amod van NOUN ADJ []
# van pobj than ADP NOUN [the, old]
# , punct was AUX PUNCT []
# but cc was AUX CCONJ []
# still advmod lacked VERB ADV []
# lacked conj was AUX VERB [still, control]
# a det control NOUN DET []
# separate amod control NOUN ADJ []
# control dobj lacked VERB NOUN [a, separate, for]
# for prep control NOUN ADP [front]
# the det front NOUN DET []
# front pobj for ADP NOUN [the, and, back]
# and cc front NOUN CCONJ []
# back conj front NOUN NOUN []
# . punct was AUX PUNCT []
#   dep was AUX SPACE []
# What pobj with ADP PRON []
# I nsubj was AUX PRON []
# was csubj was AUX AUX [I, disappointed]
# most advmod disappointed ADJ ADV []
# disappointed acomp was AUX ADJ [most, with]
# with prep disappointed ADJ ADP [What]
# was ROOT was AUX AUX [ , was, lost, .]
# that mark lost VERB PRON []
# in prep lost VERB ADP [moving]
# moving pcomp in ADP VERB [up, years]
# up prt moving VERB ADP []
# five nummod years NOUN NUM []
# years npadvmod moving VERB NOUN [five]
# , punct lost VERB PUNCT []
# I nsubj lost VERB PRON []
# lost ccomp was AUX VERB [that, in, ,, I, room, ,, ability, were]
# driver compound room NOUN NOUN []
# room dobj lost VERB NOUN [driver]
# , punct lost VERB PUNCT []
# the det ability NOUN DET []
# ability dobj lost VERB NOUN [the, adjust, ,, and, seats]
# to aux adjust VERB PART []
# adjust acl ability NOUN VERB [to, wheel, to]
# the det wheel NOUN DET []
# steering compound wheel NOUN NOUN []
# wheel dobj adjust VERB NOUN [the, steering]
# to prep adjust VERB ADP [like]
# where advmod like VERB SCONJ []
# I nsubj like VERB PRON []
# like pcomp to ADP VERB [where, I, it]
# it dobj like VERB PRON []
# , punct ability NOUN PUNCT []
# and cc ability NOUN CCONJ []
# the det seats NOUN DET []
# passenger compound seats NOUN NOUN []
# seats conj ability NOUN NOUN [the, passenger, ,]
# , punct seats NOUN PUNCT []
# by prep were AUX ADP [accounts]
# all det accounts NOUN DET []
# accounts pobj by ADP NOUN [all]
# were conj lost VERB AUX [by, comfortable]
# less advmod comfortable ADJ ADV []
# comfortable acomp were AUX ADJ [less]
# . punct was AUX PUNCT []
#   dep is AUX SPACE []
# What dobj noticed VERB PRON []
# I nsubj noticed VERB PRON []
# noticed csubj is AUX VERB [What, I, in]
# in prep noticed VERB ADP [driving]
# driving pobj in ADP NOUN []
# is ROOT is AUX AUX [ , noticed, had, .]
# that mark had VERB SCONJ []
# the det vehicle NOUN DET []
# vehicle nsubj had VERB NOUN [the]
# had ccomp is AUX VERB [that, vehicle, radius]
# a det radius NOUN DET []
# very advmod large ADJ ADV []
# large amod radius NOUN ADJ [very]
# turning compound radius NOUN NOUN []
# radius dobj had VERB NOUN [a, large, turning]
# . punct is AUX PUNCT []
#   dep   SPACE SPACE [difficult, .]
# Very advmod difficult ADJ ADV []
# difficult acomp   SPACE ADJ [Very, maneuver]
# to aux maneuver VERB PART []
# maneuver xcomp difficult ADJ VERB [to, in]
# in prep maneuver VERB ADP [traffic]
# traffic pobj in ADP NOUN []
# . punct   SPACE PUNCT []
# Sweet compound van NOUN PROPN []
# van ROOT van NOUN NOUN [Sweet]
# This det van PROPN DET []
# van nsubj rocks VERB PROPN [This]
# rocks dep lots NOUN VERB [van]
# its poss best ADJ PRON []
# the det best ADJ DET []
# best amod lots NOUN ADJ [its, the]
# , punct lots NOUN PUNCT []
# lots ROOT lots NOUN NOUN [rocks, best, ,, of, .]
# of prep lots NOUN ADP [room]
#  dep room NOUN SPACE []
# ]
# . punct lots NOUN PUNCT []
# I nsubj carry VERB PRON []
# carry ROOT carry VERB VERB [I, lot, in, and, tow, works]
# a det lot NOUN DET []
# lot dobj carry VERB NOUN [a, of]
# of prep lot NOUN ADP [cargo]
# cargo pobj of ADP NOUN []
# ]
#  SPACE PROPN []
#  dep in ADP SPACE [mine]
# and cc carry VERB CCONJ []
# i nsubj tow VERB PRON []
# tow conj carry VERB VERB [i, lot, too]
# a det lot NOUN DET []
# lot dobj tow VERB NOUN [a]
# too advmod tow VERB ADV []
# , punct works VERB PUNCT []
# it nsubj works VERB PRON []
# works conj carry VERB VERB [,, it, great, !]
# great advmod works VERB ADJ []
# ! punct works VERB PUNCT []
# Keven compound Smith PROPN PROPN []
# Smith compound Great PROPN PROPN [Keven]
# Great compound vehicle NOUN PROPN [Smith]
# work compound vehicle NOUN NOUN []
# vehicle ROOT vehicle NOUN NOUN [Great, work, .]
# . punct vehicle NOUN PUNCT []
# Drives ROOT Drives VERB VERB [nice, .]
# nice amod Drives VERB ADJ []
# . punct Drives VERB PUNCT []
# has ROOT has VERB VERB [lots, .]
# lots dobj has VERB NOUN [of]
# of prep lots NOUN ADP [room]
# room pobj of ADP NOUN []
# . punct has VERB PUNCT []
# Easy amod windows NOUN ADJ [handle]
# to aux handle VERB PART []
# handle xcomp Easy ADJ VERB [to]
# , punct windows NOUN PUNCT []
# bucket compound seats NOUN NOUN []
# seats nmod windows NOUN NOUN [bucket]
# electric amod windows NOUN ADJ []
# windows ROOT windows NOUN NOUN [Easy, ,, seats, electric]
# Not neg used VERB PART []
# what dobj be AUX PRON []
# Dodge nsubj used VERB PROPN []
# used ROOT used VERB VERB [Not, Dodge, be, .]
# to aux be AUX PART []
# be xcomp used VERB AUX [what, to, frame]
# Good amod frame NOUN ADJ []
# solid amod frame NOUN ADJ []
# frame attr be AUX NOUN [Good, solid, and, suspension]
# and cc frame NOUN CCONJ []
# suspension conj frame NOUN NOUN []
# . punct used VERB PUNCT []
#   dep power NOUN SPACE []
# Well nmod power NOUN ADV []
# equipped amod power NOUN VERB []
# , punct power NOUN PUNCT []
# full amod power NOUN ADJ []
# power ROOT power NOUN NOUN [ , Well, equipped, ,, full, .]
# . punct power NOUN PUNCT []
#   dep Gauges NOUN SPACE []
# Gauges nsubjpass designed VERB NOUN [ , and, controls]
# and cc Gauges NOUN CCONJ []
# controls conj Gauges NOUN NOUN []
# are auxpass designed VERB AUX []
# well advmod designed VERB ADV []
# designed ROOT designed VERB VERB [Gauges, are, well, and, located, .]
# and cc designed VERB CCONJ []
# located conj designed VERB VERB []
# . punct designed VERB PUNCT []
#   dep Nice PROPN SPACE []
# Nice ROOT Nice PROPN PROPN [ , drive, .]
# to aux drive VERB PART []
# drive advcl Nice PROPN VERB [to, are]
# once mark are AUX SCONJ []
# you nsubj are AUX PRON []
# are advcl drive VERB AUX [once, you, up]
# up advmod are AUX ADV [and, in]
# and cc up ADV CCONJ []
# in conj up ADV ADP []
# . punct Nice PROPN PUNCT []
#   dep room NOUN SPACE []
# No det room NOUN DET []
# leg compound room NOUN NOUN []
# room ROOT room NOUN NOUN [ , No, leg, on, .]
# on prep room NOUN ADP [side]
# passenger compound side NOUN NOUN []
# side pobj on ADP NOUN [passenger]
# . punct room NOUN PUNCT []
#   dep engine NOUN SPACE []
# 318 nummod engine NOUN NUM []
# engine nsubj seems VERB NOUN [ , 318]
# seems ROOT seems VERB VERB [engine, weak, and, are]
# very advmod weak ADJ ADV []
# weak oprd seems VERB ADJ [very]
# and cc seems VERB CCONJ []
# some det plugs NOUN DET []
# spark compound plugs NOUN NOUN []
# plugs nsubj are AUX NOUN [some, spark]
# are conj seems VERB AUX [plugs, hard, .]
# very advmod hard ADJ ADV []
# hard acomp are AUX ADJ [very, access]
# to aux access VERB PART []
# access xcomp hard ADJ VERB [to]
# . punct are AUX PUNCT []
#   dep mileage NOUN SPACE []
# Terrible amod mileage NOUN ADJ []
# gas compound mileage NOUN NOUN []
# mileage ROOT mileage NOUN NOUN [ , Terrible, gas, (, avg, ), .]
# ( punct mileage NOUN PUNCT []
# avg appos mileage NOUN NOUN [12MPG]
# 12MPG npadvmod avg NOUN PROPN []
# ) punct mileage NOUN PUNCT []
# . punct mileage NOUN PUNCT []
#   dep metal NOUN SPACE []
# Sheet compound metal NOUN PROPN []
# metal nsubj is AUX NOUN [ , Sheet]
# is ROOT is AUX AUX [metal, flimsy, lean, .]
# flimsy acomp is AUX ADJ [and, dents]
# and cc flimsy ADJ CCONJ []
# dents conj flimsy ADJ NOUN []
# if mark lean VERB SCONJ []
# you nsubj lean VERB PRON []
# lean advcl is AUX VERB [if, you, against, or, bump]
# against prep lean VERB ADP [it]
# it pobj against ADP PRON []
# or cc lean VERB CCONJ []
# bump conj lean VERB VERB [it]
# it dobj bump VERB PRON []
# . punct is AUX PUNCT []
#   dep chips NOUN SPACE []
# Paint compound chips NOUN NOUN []
# chips ROOT chips NOUN NOUN [ , Paint, and, scratches, .]
# and cc chips NOUN CCONJ []
# scratches conj chips NOUN VERB [easily]
# very advmod easily ADV ADV []
# easily advmod scratches VERB ADV [very]
# . punct chips NOUN PUNCT []
#   dep door NOUN SPACE []
# Sliding amod door NOUN PROPN []
# side compound door NOUN NOUN []
# door nsubj jumped VERB NOUN [ , Sliding, side]
# jumped ROOT jumped VERB VERB [door, track, and, scraped, .]
# the det track NOUN DET []
# track dobj jumped VERB NOUN [the]
# and cc jumped VERB CCONJ []
# scraped conj jumped VERB VERB [side]
# the det side NOUN DET []
# whole amod side NOUN ADJ []
# side dobj scraped VERB NOUN [the, whole, of]
# of prep side NOUN ADP [van]
# the det van PROPN DET []
# van pobj of ADP PROPN [the]
# . punct jumped VERB PUNCT []
#   dep door NOUN SPACE []
# Rear compound door NOUN PROPN []
# door ROOT door NOUN NOUN [ , Rear, caught, .]
# caught acl door NOUN VERB [in, and, pulled]
# in prep caught VERB ADP [wind]
# wind pobj in ADP NOUN []
# and cc caught VERB CCONJ []
# pulled conj caught VERB VERB [bolts, out]
# bolts dobj pulled VERB NOUN []
# out prep pulled VERB ADP [of]
# of prep out ADP ADP [frame]
# frame pobj of ADP NOUN []
# . punct door NOUN PUNCT []
#   dep windshields NOUN SPACE []
# Three nummod windshields NOUN NUM []
# front amod windshields NOUN ADJ []
# windshields ROOT windshields NOUN NOUN [ , Three, front, in, point, .]
# in prep windshields NOUN ADP [years]
# three nummod years NOUN NUM []
# years pobj in ADP NOUN [three]
# ( punct point NOUN PUNCT []
# stress compound point NOUN NOUN []
# point parataxis windshields NOUN NOUN [(, stress, in, ?, )]
# in prep point NOUN ADP [center]
# center pobj in ADP NOUN []
# ? punct point NOUN PUNCT []
# ) punct point NOUN PUNCT []
# . punct windshields NOUN PUNCT []
#   dep problems NOUN SPACE []
# No nmod problems NOUN PRON []
# mechanical amod problems NOUN ADJ []
# problems ROOT problems NOUN NOUN [ , No, mechanical, with, .]
# with prep problems NOUN ADP [train]
# drive compound train NOUN NOUN []
# train pobj with ADP NOUN [drive]
# . punct problems NOUN PUNCT []
#   dep   SPACE SPACE [Reliable, .]
# Reliable amod   SPACE ADJ []
# . punct   SPACE PUNCT []
#   dep quality NOUN SPACE []
# Still advmod quality NOUN ADV []
# not neg quality NOUN PART []
# the det quality NOUN DET []
# quality ROOT quality NOUN NOUN [ , Still, not, the, had]
# my poss vans NOUN PRON []
# older amod vans NOUN ADJ []
# Dodge compound vans NOUN PROPN []
# vans nsubj had VERB NOUN [my, older, Dodge]
# had relcl quality NOUN VERB [vans, .]
# . punct had VERB PUNCT []
# 2001 nummod dodge PROPN NUM []
# dodge ROOT dodge PROPN PROPN [2001, 1500, van, rust]
# 1500 nummod dodge PROPN NUM []
# ram compound van PROPN PROPN []
# van appos dodge PROPN PROPN [ram]
# some det rust NOUN DET []
# very advmod early ADJ ADV []
# early amod rust NOUN ADJ [very]
# body compound rust NOUN NOUN []
# rust appos dodge PROPN NOUN [some, early, body, on]
# on prep rust NOUN ADP [roof]
# roof pobj on ADP NOUN []
# Failur nsubj lurking VERB PROPN []
# is aux lurking VERB AUX []
# lurking ROOT lurking VERB VERB [Failur, is, in, Purchased, .]
# in prep lurking VERB ADP [corner]
# every det corner NOUN DET []
# corner pobj in ADP NOUN [every]
# Purchased advcl lurking VERB VERB [vehicle, in, with]
# the det vehicle NOUN DET []
# vehicle dobj Purchased VERB NOUN [the]
# in prep Purchased VERB ADP [hand]
# 2003 nummod hand NOUN NUM []
# second amod hand NOUN ADJ []
# hand pobj in ADP NOUN [2003, second]
# with prep Purchased VERB ADP [miles]
# 15000 nummod miles NOUN NUM []
# miles pobj with ADP NOUN [15000, from]
# from prep miles NOUN ADP [owner]
# the det owner NOUN DET []
# owner pobj from ADP NOUN [the, (, operator]
# ( punct owner NOUN PUNCT []
# a det operator NOUN DET []
# one nummod operator NOUN NUM []
# driver compound operator NOUN NOUN []
# operator appos owner NOUN NOUN [a, one, driver, ,, not, rental, )]
# , punct operator NOUN PUNCT []
# not neg operator NOUN PART []
# rental appos operator NOUN ADJ []
# ) punct operator NOUN PUNCT []
# . punct lurking VERB PUNCT []
# This det review NOUN DET []
# review nsubjpass written VERB NOUN [This]
# was auxpass written VERB AUX []
# written ROOT written VERB VERB [review, was, in, with, !]
# in prep written VERB ADP [2017]
# 2017 pobj in ADP NUM []
# with prep written VERB ADP [miles]
# only advmod 110000 NUM ADV []
# 110000 nummod miles NOUN NUM [only]
# miles pobj with ADP NOUN [110000, on]
# on prep miles NOUN ADP [it]
# it pobj on ADP PRON []
# ! punct written VERB PUNCT []
# It nsubj been AUX PRON []
# has aux been AUX AUX []
# been ROOT been AUX AUX [It, has, van, but, without, .]
# a det van NOUN DET []
# great amod van NOUN ADJ []
# service compound van NOUN NOUN []
# van attr been AUX NOUN [a, great, service, for]
# for prep van NOUN ADP [business]
# my poss business NOUN PRON []
# business pobj for ADP NOUN [my]
# but cc been AUX CCONJ []
# not neg without ADP PART []
# without conj been AUX ADP [not, flaws]
# flaws pobj without ADP NOUN []
# . punct been AUX PUNCT []
# After mark expired VERB SCONJ []
# warranty nsubj expired VERB NOUN []
# expired ROOT expired VERB VERB [After, warranty, begin, .]
# problems nsubj begin VERB NOUN []
# begin ccomp expired VERB VERB [problems]
# . punct expired VERB PUNCT []
# Had ROOT Had VERB VERB [replace, .]
# to aux replace VERB PART []
# replace xcomp Had VERB VERB [to, controller, times]
# computer compound controller NOUN NOUN []
# controller dobj replace VERB NOUN [computer]
# few amod times NOUN ADJ []
# times npadvmod replace VERB NOUN [few]
# . punct Had VERB PUNCT []
# Fuel compound hose NOUN NOUN []
# hose nsubj went VERB NOUN [Fuel]
# went ROOT went VERB VERB [hose, bad, broke, .]
# bad acomp went VERB ADJ []
# , punct broke VERB PUNCT []
# chair compound adjustment NOUN NOUN []
# adjustment compound lever NOUN NOUN [chair]
# lever nsubj broke VERB NOUN [adjustment]
# broke conj went VERB VERB [,, lever, ,, repairs, ,, replaced]
# , punct broke VERB PUNCT []
# minor amod repairs NOUN ADJ []
# repairs npadvmod broke VERB NOUN [minor, here]
# here advmod repairs NOUN ADV [and, there]
# and cc here ADV CCONJ []
# there conj here ADV ADV []
# , punct broke VERB PUNCT []
# water compound pump NOUN NOUN []
# pump nsubj replaced VERB NOUN [water]
# replaced conj broke VERB VERB [pump, ,, replaced]
# , punct replaced VERB PUNCT []
# temperature compound control NOUN NOUN []
# control compound unit NOUN NOUN [temperature]
# unit nsubj replaced VERB NOUN [control]
# replaced conj replaced VERB VERB [unit, ,, replaced]
# , punct replaced VERB PUNCT []
# gas compound tank NOUN NOUN []
# tank nsubj replaced VERB NOUN [gas, and, pump]
# and cc tank NOUN CCONJ []
# pump conj tank NOUN NOUN []
# replaced conj replaced VERB VERB [tank]
# . punct went VERB PUNCT []
# Using advcl say VERB VERB [expenses]
# a det expenses NOUN DET []
# very advmod accurate ADJ ADV []
# accurate amod expenses NOUN ADJ [very]
# repair compound expenses NOUN NOUN []
# expenses dobj Using VERB NOUN [a, accurate, repair, controlled]
# controlled acl expenses NOUN VERB [by]
# by agent controlled VERB ADP [analysis]
# business compound analysis NOUN NOUN []
# analysis pobj by ADP NOUN [business]
# I nsubj say VERB PRON []
# can aux say VERB AUX []
# say ROOT say VERB VERB [Using, I, can, is, .]
# that mark is AUX SCONJ []
# the det cost NOUN DET []
# average amod cost NOUN ADJ []
# repair compound cost NOUN NOUN []
# cost nsubj is AUX NOUN [the, average, repair]
# is ccomp say VERB AUX [that, cost, 600]
# around quantmod 600 NUM ADP []
# $ quantmod 600 NUM SYM []
# 600 attr is AUX NUM [around, $, per]
# per prep 600 NUM ADP [year]
# year pobj per ADP NOUN []
# . punct say VERB PUNCT []
# This det vehicle NOUN DET []
# vehicle nsubj go VERB NOUN [This]
# ca aux go VERB AUX []
# n't neg go VERB PART []
# go ROOT go VERB VERB [vehicle, ca, n't, trips, be, .]
# farther advmod 10 NUM ADV []
# than quantmod 10 NUM ADP []
# 10 nummod trips NOUN NUM [farther, than]
# trips dobj go VERB NOUN [10, without]
# without prep trips NOUN ADP [worrying]
# me nsubj worrying VERB PRON []
# worrying pcomp without ADP VERB [me]
# when advmod be AUX SCONJ []
# would aux be AUX AUX []
# be advcl go VERB AUX [when, would, problem]
# the det problem NOUN DET []
# next amod problem NOUN ADJ []
# problem attr be AUX NOUN [the, next]
# . punct go VERB PUNCT []
# Dealer compound sticker NOUN NOUN []
# sticker nsubj say VERB NOUN [Dealer]
# say ROOT say VERB VERB [sticker, miles, but, show, .]
# 12/15 nummod miles NOUN NUM []
# miles npadvmod say VERB NOUN [12/15, per]
# per prep miles NOUN ADP [gallon]
# gallon pobj per ADP NOUN []
# but cc say VERB CCONJ []
# with prep show VERB ADP [driving]
# very advmod conservative ADJ ADV []
# conservative amod driving VERB ADJ [very]
# driving pcomp with ADP VERB [conservative, records]
# my poss records NOUN PRON []
# records dobj driving VERB NOUN [my]
# show conj say VERB VERB [with, miles]
# 17 nummod miles NOUN NUM []
# miles dobj show VERB NOUN [17, per]
# per prep miles NOUN ADP [gallon]
# gallon pobj per ADP NOUN []
# . punct say VERB PUNCT []
# Overall advmod think VERB ADV []
# I nsubj think VERB PRON []
# do aux think VERB AUX []
# n't neg think VERB PART []
# think ROOT think VERB VERB [Overall, I, do, n't, 's, is, .]
# it nsubj 's AUX PRON []
# 's ccomp think VERB AUX [it, value, but, being]
# the det value NOUN DET []
# best amod value NOUN ADJ []
# value attr 's AUX NOUN [the, best, for]
# for prep value NOUN ADP [vehicle]
# vehicle pobj for ADP NOUN []
# but cc 's AUX CCONJ []
# being conj 's AUX AUX [optimistic, am]
# optimistic acomp being AUX ADJ []
# as mark am AUX SCONJ []
# I nsubj am AUX PRON []
# am advcl being AUX AUX [as, I, it]
# it attr am AUX PRON []
# is ccomp think VERB AUX [not, worst, either]
# not neg is AUX PART []
# the det worst ADJ DET []
# worst attr is AUX ADJ [the]
# either advmod is AUX ADV []
# . punct think VERB PUNCT []
# Hope ROOT Hope VERB VERB [helps, .]
# this nsubj helps VERB PRON []
# helps ccomp Hope VERB VERB [this]
# . punct Hope VERB PUNCT []
# Great compound Van PROPN PROPN []
# Van compound Bought PROPN PROPN [Great]
# Bought nsubj used VERB PROPN [Van]
# used ROOT used VERB VERB [Bought, with, is]
# with prep used VERB ADP [34k]
# 34k pobj with ADP NOUN [,, package]
# , punct 34k NOUN PUNCT []
# the det package NOUN DET []
# conversion compound package NOUN NOUN []
# package appos 34k NOUN NOUN [the, conversion, by]
# by prep package NOUN ADP [automotive]
# Elk compound automotive NOUN PROPN []
# automotive pobj by ADP NOUN [Elk]
# is ccomp used VERB AUX [rate, .]
# top amod rate NOUN ADJ []
# rate attr is AUX NOUN [top]
# . punct is AUX PUNCT []
# Has ROOT Has VERB VERB [leather, .]
# leather nsubj Has VERB NOUN [,, cd, ,, goodies]
# , punct leather NOUN PUNCT []
# cd conj leather NOUN NOUN [,, dvd]
# , punct cd NOUN PUNCT []
# dvd conj cd NOUN NOUN [,, air]
# , punct dvd NOUN PUNCT []
# rear amod air NOUN ADJ []
# air conj dvd NOUN NOUN [rear, ,, tv]
# , punct air NOUN PUNCT []
# tv conj air NOUN NOUN [,, stereo]
# , punct tv NOUN PUNCT []
# rear amod stereo NOUN ADJ []
# stereo conj tv NOUN NOUN [rear]
# , punct leather NOUN PUNCT []
# all predet goodies NOUN DET []
# the det goodies NOUN DET []
# goodies appos leather NOUN NOUN [all, the]
# . punct Has VERB PUNCT []
# Very advmod easy ADJ ADV []
# easy advcl is AUX ADJ [Very, drive]
# to aux drive VERB PART []
# drive xcomp easy ADJ VERB [to, despite]
# despite prep drive VERB SCONJ [size]
# its poss size NOUN PRON []
# size pobj despite SCONJ NOUN [its]
# , punct is AUX PUNCT []
# ride nsubj is AUX NOUN []
# is ROOT is AUX AUX [easy, ,, ride, nice, inside, .]
# nice acomp is AUX ADJ [and, quiet]
# and cc nice ADJ CCONJ []
# quiet conj nice ADJ ADJ []
# inside advmod is AUX ADV []
# . punct is AUX PUNCT []
# With prep are AUX ADP [engines]
# the det engines NOUN DET []
# 318 nummod engines NOUN NUM []
# engines pobj With ADP NOUN [the, 318, and, service]
# and cc engines NOUN CCONJ []
# regular amod service NOUN ADJ []
# service conj engines NOUN NOUN [regular]
# these det things NOUN DET []
# things nsubj are AUX NOUN [these]
# are ROOT are AUX AUX [With, things, bullet, -, proof, .]
# allmost advmod bullet NOUN ADV []
# bullet attr are AUX NOUN [allmost]
# - punct are AUX NOUN []
# proof attr are AUX NOUN []
# . punct are AUX PUNCT []
# As mark produce VERB SCONJ []
# most amod manufacturers NOUN ADJ []
# manufacturers nsubj produce VERB NOUN [most]
# produce advcl feel VERB VERB [As, manufacturers, few, more, and, ones]
# very advmod few ADJ ADV []
# few dobj produce VERB ADJ [very, of]
# of prep few ADJ ADP [conversions]
# the det conversions NOUN DET []
# large amod conversions NOUN ADJ []
# van compound conversions NOUN PROPN []
# conversions pobj of ADP NOUN [the, large, van]
# any advmod more ADV PRON []
# more advmod produce VERB ADV [any]
# and cc produce VERB CCONJ []
# the det ones NOUN DET []
# new amod ones NOUN ADJ []
# ones conj produce VERB NOUN [the, new, costing, are]
# costing acl ones NOUN VERB [50k]
# 50k dobj costing VERB PRON []
# that nsubj are AUX PRON []
# are relcl ones NOUN AUX [that, available]
# available acomp are AUX ADJ []
# , punct feel VERB PUNCT []
# I nsubj feel VERB PRON []
# feel ROOT feel VERB VERB [produce, ,, I, stole, .]
# that mark stole VERB SCONJ []
# for prep stole VERB ADP [20k]
# 20k pobj for ADP NOUN []
# I nsubj stole VERB PRON []
# stole ccomp feel VERB VERB [that, for, I, thing]
# this det thing NOUN DET []
# thing dobj stole VERB NOUN [this]
# . punct feel VERB PUNCT []
# One nsubj is AUX NUM [of]
# of prep One NUM ADP [things]
# the det things NOUN DET []
# best amod things NOUN ADJ []
# things pobj of ADP NOUN [the, best]
# is ROOT is AUX AUX [One, 's, .]
# it nsubj 's AUX PRON []
# 's ccomp is AUX AUX [it, still, under, with]
# still advmod 's AUX ADV []
# under prep 's AUX ADP [warranty]
# warranty pobj under ADP NOUN []
# with prep 's AUX ADP [plan]
# Chryslers nmod plan NOUN PROPN [7/70]
# 7/70 nummod Chryslers PROPN NUM []
# plan pobj with ADP NOUN [Chryslers]
# . punct is AUX PUNCT []
# These nsubj are AUX PRON []
# are ccomp 's AUX AUX [These, way, ,]
# the det way NOUN DET []
# only amod way NOUN ADJ []
# way attr are AUX NOUN [the, only, travel]
# to aux travel VERB PART []
# travel relcl way NOUN VERB [to]
# , punct are AUX PUNCT []
# if mark buying VERB SCONJ []
# you nsubj buying VERB PRON []
# are aux buying VERB AUX []
# buying advcl 's AUX VERB [if, you, are, for]
# for prep buying VERB ADP [use]
# everyday amod use NOUN ADJ []
# use pobj for ADP NOUN [everyday]
# , punct 's AUX PUNCT []
# it nsubj 's AUX PRON []
# 's ROOT 's AUX AUX [are, buying, ,, it, probably, not, vehicle, .]
# probably advmod 's AUX ADV []
# not neg 's AUX PART []
# the det vehicle NOUN DET []
# right amod vehicle NOUN ADJ []
# vehicle attr 's AUX NOUN [the, right]
# . punct 's AUX PUNCT []
# 2003 nummod Van PROPN NUM []
# Conversion compound Van PROPN PROPN []
# Van ROOT Van PROPN PROPN [2003, Conversion]
# This nsubj is AUX PRON []
# is ROOT is AUX AUX [This, left, .]
# a det left NOUN DET []
# left attr is AUX NOUN [a, over]
# over prep left NOUN ADP [van]
# new amod van PROPN PROPN []
# van pobj over ADP PROPN [new]
# . punct is AUX PUNCT []
# Great amod deal NOUN ADJ []
# deal ROOT deal NOUN NOUN [Great]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_59512/1002132685.py in <module>
#       1 for sentence in df_csv['review']:
# ----> 2     doc = nlp(sentence)
#       3     for token in doc:
#       4          print(token.text, token.dep_, token.head.text, token.head.pos_,
#       5       token.pos_,[child for child in token.children])
#
# ~/Divyansh/projects/senti_random_forest/packages/lib/python3.8/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1003         DOCS: https://spacy.io/api/language#call
#    1004         """
# -> 1005         doc = self._ensure_doc(text)
#    1006         if component_cfg is None:
#    1007             component_cfg = {}
#
# ~/Divyansh/projects/senti_random_forest/packages/lib/python3.8/site-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1094         if isinstance(doc_like, str):
#    1095             return self.make_doc(doc_like)
# -> 1096         raise ValueError(Errors.E866.format(type=type(doc_like)))
#    1097
#    1098     def _ensure_doc_with_context(self, doc_like: Union[str, Doc], context: Any) -> Doc:
#
# ValueError: [E866] Expected a string or 'Doc' as input, but got: <class 'float'>.

# %%
competitors = ['Chevy','chevy','Ford','ford','Nissan','nissan','Honda','honda','Chevrolet','chevrolet','Volkswagen','volkswagen','benz','Benz','Mercedes','mercedes','subaru','Subaru','VW']

# %%
aspect_terms = []
comp_terms = []
easpect_terms = []
ecomp_terms = []
enemy = []
for x in tqdm(range(len(df_csv['review']))):
    amod_pairs = []
    advmod_pairs = []
    compound_pairs = []
    xcomp_pairs = []
    neg_pairs = []
    eamod_pairs = []
    eadvmod_pairs = []
    ecompound_pairs = []
    eneg_pairs = []
    excomp_pairs = []
    enemlist = []
    if len(str(df_csv['review'][x])) != 0:
        lines = str(df_csv['review'][x]).replace('*',' ').replace('-',' ').replace('so ',' ').replace('be ',' ').replace('are ',' ').replace('just ',' ').replace('get ','').replace('were ',' ').replace('When ','').replace('when ','').replace('again ',' ').replace('where ','').replace('how ',' ').replace('has ',' ').replace('Here ',' ').replace('here ',' ').replace('now ',' ').replace('see ',' ').replace('why ',' ').split('.')       
        for line in lines:
            enem_list = []
            for eny in competitors:
                enem = re.search(eny,line)
                if enem is not None:
                    enem_list.append(enem.group())
            if len(enem_list)==0:
                doc = nlp(line)
                str1=''
                str2=''
                for token in doc:
                    if token.pos_ == 'NOUN':
                        for j in token.lefts:
                            if j.dep_ == 'compound':
                                compound_pairs.append((j.text+' '+token.text,token.text))
                            if j.dep_ == 'amod' and j.pos_ == 'ADJ': #primary condition
                                str1 = j.text+' '+token.text
                                amod_pairs.append(j.text+' '+token.text)
                                for k in j.lefts:
                                    if k.dep_ == 'advmod': #secondary condition to get adjective of adjectives
                                        str2 = k.text+' '+j.text+' '+token.text
                                        amod_pairs.append(k.text+' '+j.text+' '+token.text)
                                mtch = re.search(re.escape(str1),re.escape(str2))
                                if mtch is not None:
                                    amod_pairs.remove(str1)
                    if token.pos_ == 'VERB':
                        for j in token.lefts:
                            if j.dep_ == 'advmod' and j.pos_ == 'ADV':
                                advmod_pairs.append(j.text+' '+token.text)
                            if j.dep_ is 'neg' and j.pos_ is 'ADV':
                                neg_pairs.append(j.text+' '+token.text)
                        for j in token.rights:
                            if j.dep_ is 'advmod'and j.pos_ is 'ADV':
                                advmod_pairs.append(token.text+' '+j.text)
                    if token.pos_ is 'ADJ':
                        for j,h in zip(token.rights,token.lefts):
                            if j.dep_ is 'xcomp' and h.dep_ is not 'neg':
                                for k in j.lefts:
                                    if k.dep_ is 'aux':
                                        xcomp_pairs.append(token.text+' '+k.text+' '+j.text)
                            elif j.dep_ is 'xcomp' and h.dep_ is 'neg':
                                if k.dep_ is 'aux':
                                        neg_pairs.append(h.text +' '+token.text+' '+k.text+' '+j.text)
            
            else:
                enemlist.append(enem_list)
                doc = nlp(line)
                str1=''
                str2=''
                for token in doc:
                    if token.pos_ is 'NOUN':
                        for j in token.lefts:
                            if j.dep_ == 'compound':
                                ecompound_pairs.append((j.text+' '+token.text,token.text))
                            if j.dep_ is 'amod' and j.pos_ is 'ADJ': #primary condition
                                str1 = j.text+' '+token.text
                                eamod_pairs.append(j.text+' '+token.text)
                                for k in j.lefts:
                                    if k.dep_ is 'advmod': #secondary condition to get adjective of adjectives
                                        str2 = k.text+' '+j.text+' '+token.text
                                        eamod_pairs.append(k.text+' '+j.text+' '+token.text)
                                mtch = re.search(re.escape(str1),re.escape(str2))
                                if mtch is not None:
                                    eamod_pairs.remove(str1)
                    if token.pos_ is 'VERB':
                        for j in token.lefts:
                            if j.dep_ is 'advmod' and j.pos_ is 'ADV':
                                eadvmod_pairs.append(j.text+' '+token.text)
                            if j.dep_ is 'neg' and j.pos_ is 'ADV':
                                eneg_pairs.append(j.text+' '+token.text)
                        for j in token.rights:
                            if j.dep_ is 'advmod'and j.pos_ is 'ADV':
                                eadvmod_pairs.append(token.text+' '+j.text)
                    if token.pos_ is 'ADJ':
                        for j in token.rights:
                            if j.dep_ is 'xcomp':
                                for k in j.lefts:
                                    if k.dep_ is 'aux':
                                        excomp_pairs.append(token.text+' '+k.text+' '+j.text)
        pairs = list(set(amod_pairs+advmod_pairs+neg_pairs+xcomp_pairs))
        epairs = list(set(eamod_pairs+eadvmod_pairs+eneg_pairs+excomp_pairs))
        for i in range(len(pairs)):
            if len(compound_pairs)!=0:
                for comp in compound_pairs:
                    mtch = re.search(re.escape(comp[1]),re.escape(pairs[i]))
                    if mtch is not None:
                        pairs[i] = pairs[i].replace(mtch.group(),comp[0])
        for i in range(len(epairs)):
            if len(ecompound_pairs)!=0:
                for comp in ecompound_pairs:
                    mtch = re.search(re.escape(comp[1]),re.escape(epairs[i]))
                    if mtch is not None:
                        epairs[i] = epairs[i].replace(mtch.group(),comp[0])
            
    aspect_terms.append(pairs)
    comp_terms.append(compound_pairs)
    easpect_terms.append(epairs)
    ecomp_terms.append(ecompound_pairs)
    enemy.append(enemlist)
df_csv['compound_nouns'] = comp_terms
df_csv['aspect_keywords'] = aspect_terms
df_csv['competition'] = enemy
df_csv['competition_comp_nouns'] = ecomp_terms
df_csv['competition_aspects'] = easpect_terms
df_csv.head()
# Out:
# <>:49: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:49: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:52: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:52: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:54: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:56: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:56: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:58: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:60: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:60: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:70: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:78: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:84: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:86: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:86: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:91: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:91: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:93: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:95: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:49: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:49: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:52: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:52: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:54: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:56: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:56: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:58: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:60: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:60: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:70: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:78: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:84: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:86: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:86: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:91: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:91: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:93: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:95: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_59512/2374202546.py:49: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'neg' and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:49: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'neg' and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:52: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'advmod'and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:52: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'advmod'and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:54: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if token.pos_ is 'ADJ':
# /tmp/ipykernel_59512/2374202546.py:56: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'xcomp' and h.dep_ is not 'neg':
# /tmp/ipykernel_59512/2374202546.py:56: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if j.dep_ is 'xcomp' and h.dep_ is not 'neg':
# /tmp/ipykernel_59512/2374202546.py:58: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if k.dep_ is 'aux':
# /tmp/ipykernel_59512/2374202546.py:60: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif j.dep_ is 'xcomp' and h.dep_ is 'neg':
# /tmp/ipykernel_59512/2374202546.py:60: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif j.dep_ is 'xcomp' and h.dep_ is 'neg':
# /tmp/ipykernel_59512/2374202546.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if k.dep_ is 'aux':
# /tmp/ipykernel_59512/2374202546.py:70: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if token.pos_ is 'NOUN':
# /tmp/ipykernel_59512/2374202546.py:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'amod' and j.pos_ is 'ADJ': #primary condition
# /tmp/ipykernel_59512/2374202546.py:74: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'amod' and j.pos_ is 'ADJ': #primary condition
# /tmp/ipykernel_59512/2374202546.py:78: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if k.dep_ is 'advmod': #secondary condition to get adjective of adjectives
# /tmp/ipykernel_59512/2374202546.py:84: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if token.pos_ is 'VERB':
# /tmp/ipykernel_59512/2374202546.py:86: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'advmod' and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:86: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'advmod' and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'neg' and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'neg' and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:91: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'advmod'and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:91: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'advmod'and j.pos_ is 'ADV':
# /tmp/ipykernel_59512/2374202546.py:93: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if token.pos_ is 'ADJ':
# /tmp/ipykernel_59512/2374202546.py:95: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j.dep_ is 'xcomp':
# /tmp/ipykernel_59512/2374202546.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if k.dep_ is 'aux':
# 100%|███████████████████████████████████████████████| 11552/11552 [05:27<00:00, 35.31it/s]
#   Unnamed: 0                  Review_Date   Author_Name  \
# 0          0   on 10/13/05 15:30 PM (PDT)     roadking
# 1          1   on 07/17/05 21:59 PM (PDT)         Mark
# 2          2   on 07/16/02 00:00 AM (PDT)    Tom Sheer
# 3          3   on 12/29/07 21:57 PM (PST)  Keven Smith
# 4          4   on 02/09/05 18:52 PM (PST)       VanMan
#
#                                        Vehicle_Title  \
# 0  2002 Dodge Ram Cargo Van 1500 3dr Van (3.9L 6c...
# 1  2002 Dodge Ram Cargo Van 3500 3dr Ext Van (5.2...
# 2  2002 Dodge Ram Cargo Van 3500 Maxi 3dr Ext Van...
# 3  2001 Dodge Ram Cargo Van 2500 Maxi 3dr Ext Van...
# 4  2001 Dodge Ram Cargo Van 1500 3dr Van (3.9L 6c...
#
#                 Review_Title  \
# 0     Great delivery vehicle
# 1             Disappointmnet
# 2                  Sweet van
# 3                Keven Smith
# 4  Not what Dodge used to be
#
#                                               Review  Rating  \
# 0   It's been a great delivery vehicle for my caf...   4.625
# 1   Bought this car as a commuter vehicle for a v...   2.125
# 2   This van rocks its the best, lots of \rroom. ...   5.000
# 3   Great work vehicle. Drives nice. has lots of ...   4.500
# 4   Good solid frame and suspension.  Well equipp...   2.875
#
#                                               review  \
# 0  Great delivery vehicle It's been a great deliv...
# 1  Disappointmnet Bought this car as a commuter v...
# 2  Sweet van This van rocks its the best, lots of...
# 3  Keven Smith Great work vehicle. Drives nice. h...
# 4  Not what Dodge used to be Good solid frame and...
#
#                                       compound_nouns  \
# 0  [(delivery vehicle, vehicle), (delivery vehicl...
# 1  [(commuter vehicle, vehicle), (van pool, pool)...
# 2                                 [(Sweet van, van)]
# 3   [(work vehicle, vehicle), (bucket seats, seats)]
# 4  [(leg room, room), (passenger side, side), (sp...
#
#                                      aspect_keywords competition  \
# 0  [normal maintenance items, great delivery deli...          []
# 1  [old van, separate control, very large turning...          []
# 2                               [best lots, tow too]          []
# 3                                 [electric windows]          []
# 4  [scratches easily, full power, well designed, ...          []
#
#   competition_comp_nouns competition_aspects
# 0                     []                  []
# 1                     []                  []
# 2                     []                  []
# 3                     []                  []
# 4                     []                  []

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
import operator

# %%
sentiment = []
for i in range(len(df_csv)):
    score_dict={'pos':0,'neg':0,'neu':0}
    if len(df_csv['aspect_keywords'][i])!=0: 
        for aspects in df_csv['aspect_keywords'][i]:
            sent = analyzer.polarity_scores(aspects)
            score_dict['neg'] += sent['neg']
            score_dict['pos'] += sent['pos']
        #score_dict['neu'] += sent['neu']
        sentiment.append(max(score_dict.items(), key=operator.itemgetter(1))[0])
    else:
        sentiment.append('NaN')
df_csv['sentiment'] = sentiment
df_csv.head()
# Out:
#   Unnamed: 0                  Review_Date   Author_Name  \
# 0          0   on 10/13/05 15:30 PM (PDT)     roadking
# 1          1   on 07/17/05 21:59 PM (PDT)         Mark
# 2          2   on 07/16/02 00:00 AM (PDT)    Tom Sheer
# 3          3   on 12/29/07 21:57 PM (PST)  Keven Smith
# 4          4   on 02/09/05 18:52 PM (PST)       VanMan
#
#                                        Vehicle_Title  \
# 0  2002 Dodge Ram Cargo Van 1500 3dr Van (3.9L 6c...
# 1  2002 Dodge Ram Cargo Van 3500 3dr Ext Van (5.2...
# 2  2002 Dodge Ram Cargo Van 3500 Maxi 3dr Ext Van...
# 3  2001 Dodge Ram Cargo Van 2500 Maxi 3dr Ext Van...
# 4  2001 Dodge Ram Cargo Van 1500 3dr Van (3.9L 6c...
#
#                 Review_Title  \
# 0     Great delivery vehicle
# 1             Disappointmnet
# 2                  Sweet van
# 3                Keven Smith
# 4  Not what Dodge used to be
#
#                                               Review  Rating  \
# 0   It's been a great delivery vehicle for my caf...   4.625
# 1   Bought this car as a commuter vehicle for a v...   2.125
# 2   This van rocks its the best, lots of \rroom. ...   5.000
# 3   Great work vehicle. Drives nice. has lots of ...   4.500
# 4   Good solid frame and suspension.  Well equipp...   2.875
#
#                                               review  \
# 0  Great delivery vehicle It's been a great deliv...
# 1  Disappointmnet Bought this car as a commuter v...
# 2  Sweet van This van rocks its the best, lots of...
# 3  Keven Smith Great work vehicle. Drives nice. h...
# 4  Not what Dodge used to be Good solid frame and...
#
#                                       compound_nouns  \
# 0  [(delivery vehicle, vehicle), (delivery vehicl...
# 1  [(commuter vehicle, vehicle), (van pool, pool)...
# 2                                 [(Sweet van, van)]
# 3   [(work vehicle, vehicle), (bucket seats, seats)]
# 4  [(leg room, room), (passenger side, side), (sp...
#
#                                      aspect_keywords competition  \
# 0  [normal maintenance items, great delivery deli...          []
# 1  [old van, separate control, very large turning...          []
# 2                               [best lots, tow too]          []
# 3                                 [electric windows]          []
# 4  [scratches easily, full power, well designed, ...          []
#
#   competition_comp_nouns competition_aspects sentiment
# 0                     []                  []       pos
# 1                     []                  []       neg
# 2                     []                  []       pos
# 3                     []                  []       pos
# 4                     []                  []       pos

# %%
int_sent = []
for sent in df_csv['sentiment']:
    if sent is 'NaN':
        int_sent.append('NaN')
    elif sent is 'pos':
        int_sent.append('1')
    else:
        int_sent.append('0')
df_csv['int_sent'] = int_sent
df_csv.head()
# Out:
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_59512/3218436051.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sent is 'NaN':
# /tmp/ipykernel_59512/3218436051.py:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif sent is 'pos':
#   Unnamed: 0                  Review_Date   Author_Name  \
# 0          0   on 10/13/05 15:30 PM (PDT)     roadking
# 1          1   on 07/17/05 21:59 PM (PDT)         Mark
# 2          2   on 07/16/02 00:00 AM (PDT)    Tom Sheer
# 3          3   on 12/29/07 21:57 PM (PST)  Keven Smith
# 4          4   on 02/09/05 18:52 PM (PST)       VanMan
#
#                                        Vehicle_Title  \
# 0  2002 Dodge Ram Cargo Van 1500 3dr Van (3.9L 6c...
# 1  2002 Dodge Ram Cargo Van 3500 3dr Ext Van (5.2...
# 2  2002 Dodge Ram Cargo Van 3500 Maxi 3dr Ext Van...
# 3  2001 Dodge Ram Cargo Van 2500 Maxi 3dr Ext Van...
# 4  2001 Dodge Ram Cargo Van 1500 3dr Van (3.9L 6c...
#
#                 Review_Title  \
# 0     Great delivery vehicle
# 1             Disappointmnet
# 2                  Sweet van
# 3                Keven Smith
# 4  Not what Dodge used to be
#
#                                               Review  Rating  \
# 0   It's been a great delivery vehicle for my caf...   4.625
# 1   Bought this car as a commuter vehicle for a v...   2.125
# 2   This van rocks its the best, lots of \rroom. ...   5.000
# 3   Great work vehicle. Drives nice. has lots of ...   4.500
# 4   Good solid frame and suspension.  Well equipp...   2.875
#
#                                               review  \
# 0  Great delivery vehicle It's been a great deliv...
# 1  Disappointmnet Bought this car as a commuter v...
# 2  Sweet van This van rocks its the best, lots of...
# 3  Keven Smith Great work vehicle. Drives nice. h...
# 4  Not what Dodge used to be Good solid frame and...
#
#                                       compound_nouns  \
# 0  [(delivery vehicle, vehicle), (delivery vehicl...
# 1  [(commuter vehicle, vehicle), (van pool, pool)...
# 2                                 [(Sweet van, van)]
# 3   [(work vehicle, vehicle), (bucket seats, seats)]
# 4  [(leg room, room), (passenger side, side), (sp...
#
#                                      aspect_keywords competition  \
# 0  [normal maintenance items, great delivery deli...          []
# 1  [old van, separate control, very large turning...          []
# 2                               [best lots, tow too]          []
# 3                                 [electric windows]          []
# 4  [scratches easily, full power, well designed, ...          []
#
#   competition_comp_nouns competition_aspects sentiment int_sent
# 0                     []                  []       pos        1
# 1                     []                  []       neg        0
# 2                     []                  []       pos        1
# 3                     []                  []       pos        1
# 4                     []                  []       pos        1
